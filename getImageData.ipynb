# %% [markdown]
# <a href="https://colab.research.google.com/github/NehaKumari500092077/Image-Processing/blob/main/getImageData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement opencv (from versions: none)
# ERROR: No matching distribution found for opencv

# %%
import cv2
imgpath = "/content/image.jpeg"
img1 = cv2.imread(imgpath)

# %%
img1
# Out:
# array([[[159, 176, 189],
#         [169, 186, 199],
#         [169, 187, 204],
#         ...,
#         [149, 177, 201],
#         [145, 173, 197],
#         [145, 173, 197]],
#
#        [[161, 178, 191],
#         [170, 187, 200],
#         [170, 188, 205],
#         ...,
#         [152, 180, 204],
#         [147, 175, 199],
#         [147, 175, 199]],
#
#        [[162, 179, 192],
#         [172, 189, 202],
#         [172, 190, 207],
#         ...,
#         [153, 181, 205],
#         [148, 176, 200],
#         [147, 175, 199]],
#
#        ...,
#
#        [[165, 171, 176],
#         [167, 173, 178],
#         [168, 174, 179],
#         ...,
#         [ 41,  52,  82],
#         [ 41,  52,  82],
#         [ 40,  51,  81]],
#
#        [[165, 171, 176],
#         [167, 173, 178],
#         [169, 175, 180],
#         ...,
#         [ 41,  52,  82],
#         [ 40,  51,  81],
#         [ 39,  50,  80]],
#
#        [[164, 170, 175],
#         [166, 172, 177],
#         [168, 174, 179],
# ...

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img1)
#cv2.waitKey()
#cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1167x1280 at 0x7F7EDCFB3910>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.imshow(img1)
plt.axis('off')
plt.show()

# %%
#resize the images using cv2
img1=cv2.resize(img1, (200, 200))#width, height
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F7EDB210F90>

# %%
#https://www.geeksforgeeks.org/python-opencv-cv2-imread-method/

#Syntax: cv2.imread(path, flag)
#path: A string representing the path of the image to be read.
#flag: It specifies the way in which image should be read. It’s default value is 1.

img1 = cv2.imread(imgpath, 0)
img1=cv2.resize(img1, (200, 200))
cv2_imshow(img1)
img1 = cv2.imread(imgpath, 1)
img1=cv2.resize(img1, (200, 200))
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7F7EDB21DE10>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F7EDB21DB10>
